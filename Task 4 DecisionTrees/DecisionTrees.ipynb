# %% [markdown]
# # Data Science: TASK-3 Prediction using Decision Tree Algorithm

# %%
# Importing libraries 
import sklearn.datasets as datasets
import pandas as pd
import matplotlib.pyplot as plt  
# %matplotlib inline
import seaborn as sns

# %%
# Loading the iris datasets
df=pd.read_csv("iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Ploting histogram for all numerical variables
df.hist(bins=10,edgecolor='black',figsize=(12,7))
plt.show()

# %%
# Splitting dataset into train and validation sets
from sklearn.model_selection import train_test_split
X, y = df.iloc[ : , 1: -1], df.iloc[ : , -1]
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state = 0, shuffle = True, test_size = 0.2)
X_train.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 137            6.4           3.1            5.5           1.8
# 84             5.4           3.0            4.5           1.5
# 27             5.2           3.5            1.5           0.2
# 127            6.1           3.0            4.9           1.8
# 132            6.4           2.8            5.6           2.2

# %%
#create Decision Tree modal
from sklearn.tree import DecisionTreeClassifier
treeModel = DecisionTreeClassifier(max_depth = 6)   
treeModel.fit(X_train, y_train)
y_preds = treeModel.predict(X_val)

# %%
#plot the modal
from sklearn.tree import plot_tree
plt.figure(figsize = (16, 16))
plot_tree(treeModel,feature_names=X.columns,class_names=y.unique(),filled = True);
